# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: c:\Users\ibrahim\.pyenv\pyenv-win\versions\3.12.3\python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import cv2

# %%
# Load the pretrained YOLOv8 model
model = YOLO("yolov8n.pt")  # Use a pretrained YOLOv8 Nano model

# Load an image
image_path = "/content/WhatsApp Image 2024-11-25 at 00.37.39_8d638f7d.jpg"  # Replace with your image path
output_path = "/content/output.jpg"    # Path to save the output image

# Perform object detection
results = model(image_path)

# Draw bounding boxes on the image
annotated_image = results[0].plot()  # Automatically draws bounding boxes and labels

# Save the image with bounding boxes
cv2.imwrite(output_path, annotated_image)

# Display the result in Colab
cv2_imshow(annotated_image)  # Use cv2_imshow instead of cv2.imshow
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 74.9MB/s]
# image 1/1 /content/WhatsApp Image 2024-11-25 at 00.37.39_8d638f7d.jpg: 640x512 1 person, 1 dog, 1 tie, 402.2ms
# Speed: 19.6ms preprocess, 402.2ms inference, 41.2ms postprocess per image at shape (1, 3, 640, 512)
# <PIL.Image.Image image mode=RGB size=308x388>

# %%
model = YOLO("yolo11m.pt")

path = "person-bicycle-car-detection.mp4"
results = model(source=path,conf=0.4)

# %%
frames = []


for frame in results:
    frames.append(frame.plot())

# %%
import cv2


first_image = frames[0]


frame_size = (first_image.shape[1], first_image.shape[0])


output_filename = 'output_video.avi'
fourcc = cv2.VideoWriter_fourcc(*'XVID')
fps = 24

out = cv2.VideoWriter(output_filename, fourcc, fps, frame_size)

for frame in frames:
    out.write(frame)

out.release()
print("Video created successfully.")
